# %%
import os
import json
import pandas as pd
results_dir = 'results'

# %%
datasets = [
    'netgpi',
    'deeploc',
    'netsurfp',
    'signalp',
    'spotrna1d',
    'nrc',
    'deepromoter',
    'histone'
    ]

algorithms = [
    'partition_graphpart_needle',
    'partition_graphpart_mmseqs2',
    'reduction_mmseqs2',
    'reduction_cdhit',
    'partition_mmseqs2',
    'partition_cdhit',
]

out_list = []

for dataset in datasets:
    for algorithm in algorithms:
        fpath = os.path.join(results_dir, f'{dataset}_{algorithm}_report.json')
        if not os.path.exists(fpath):
            continue
        data = json.load(open(fpath, 'r'))
        
        if 'graphpart' in algorithm:
            series_dict = {
                    'time_alignment': data['time_edges_complete'] - data['time_script_start'],
                    'time_partitioning': data['time_script_complete'] - data['time_edges_complete']
                }
        else:
            series_dict = {'time_partitioning': data['time_script_complete'] - data['time_script_start']}
        
        series = pd.Series(series_dict, name = f'{dataset}_{algorithm}')
        out_list.append(series)

# %%
# make dataframe and format all numbers as minutes:seconds (are seconds)
df = pd.DataFrame(out_list).fillna(0)
df = df.applymap(lambda x: f'{int(x//60)}:{int(x%60):02d}')
df
# Out:
#                                         time_alignment time_partitioning
# netgpi_partition_graphpart_needle                 9:57              0:02
# netgpi_partition_graphpart_mmseqs2                0:04              0:04
# netgpi_reduction_mmseqs2                          0:00              0:09
# netgpi_reduction_cdhit                            0:00              0:30
# netgpi_partition_mmseqs2                          0:00              0:10
# netgpi_partition_cdhit                            0:00              0:28
# deeploc_partition_graphpart_needle              499:11              0:01
# deeploc_partition_graphpart_mmseqs2               3:57              0:31
# deeploc_reduction_mmseqs2                         0:00              0:15
# deeploc_reduction_cdhit                           0:00             13:02
# deeploc_partition_mmseqs2                         0:00              0:19
# deeploc_partition_cdhit                           0:00             14:34
# netsurfp_partition_graphpart_needle            1085:36             12:00
# netsurfp_partition_graphpart_mmseqs2              7:47             15:17
# netsurfp_reduction_mmseqs2                        0:00              0:13
# netsurfp_reduction_cdhit                          0:00              9:12
# netsurfp_partition_mmseqs2                        0:00              0:19
# netsurfp_partition_cdhit                          0:00              9:24
# signalp_partition_graphpart_needle              291:22              0:48
# signalp_partition_graphpart_mmseqs2               0:44              0:37
# signalp_reduction_mmseqs2                         0:00              0:11
# signalp_reduction_cdhit                           0:00              3:19
# signalp_partition_mmseqs2                         0:00              0:16
# signalp_partition_cdhit                           0:00              3:23
# spotrna1d_partition_graphpart_needle              0:56              0:00
# spotrna1d_partition_graphpart_mmseqs2             0:02              0:00
# spotrna1d_reduction_mmseqs2                       0:00              0:21
# spotrna1d_reduction_cdhit                         0:00              0:00
# spotrna1d_partition_mmseqs2                       0:00              0:27
# spotrna1d_partition_cdhit                         0:00              0:01
# nrc_partition_graphpart_needle                   37:38              0:12
# nrc_partition_graphpart_mmseqs2                   0:04              0:16
# nrc_reduction_mmseqs2                             0:00              0:21
# nrc_reduction_cdhit                               0:00              0:02
# nrc_partition_mmseqs2                             0:00              0:35
# nrc_partition_cdhit                               0:00              0:03
# deepromoter_partition_graphpart_needle           10:15              0:00
# deepromoter_partition_graphpart_mmseqs2           0:02              0:00
# deepromoter_reduction_mmseqs2                     0:00              0:30
# deepromoter_reduction_cdhit                       0:00              0:10
# deepromoter_partition_mmseqs2                     0:00              0:32
# deepromoter_partition_cdhit                       0:00              0:10
# histone_partition_graphpart_needle              431:10              0:01
# histone_partition_graphpart_mmseqs2               0:11              0:01
# histone_reduction_mmseqs2                         0:00              0:21
# histone_reduction_cdhit                           0:00              1:01
# histone_partition_mmseqs2                         0:00              0:37
# histone_partition_cdhit                           0:00              1:03

# %%
df = pd.DataFrame(out_list)
df
# Out:
#                                          time_alignment  time_partitioning
# netgpi_partition_graphpart_needle            370.021356           3.131261
# netgpi_partition_graphpart_mmseqs2            27.582901           6.021922
# deeploc_partition_graphpart_needle         15345.758520           2.893012
# deeploc_partition_graphpart_mmseqs2         1595.437951          56.726447
# netsurfp_partition_graphpart_needle        62401.694571        1640.029875
# netsurfp_partition_graphpart_mmseqs2        4505.449518        1667.702321
# signalp_partition_graphpart_needle         18724.954155         102.917607
# signalp_partition_graphpart_mmseqs2          685.705397          66.690666
# spotrna1d_partition_graphpart_needle          31.332998           0.267120
# spotrna1d_partition_graphpart_mmseqs2          1.741057           0.270862
# nrc_partition_graphpart_needle              1309.916010          22.487980
# nrc_partition_graphpart_mmseqs2               13.840120          32.220631
# deepromoter_partition_graphpart_needle       648.561022           0.441467
# deepromoter_partition_graphpart_mmseqs2        7.017680           6.287434
# histone_partition_graphpart_needle         70672.165291           1.240771
# histone_partition_graphpart_mmseqs2           47.480396           1.664180
